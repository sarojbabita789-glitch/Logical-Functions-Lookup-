# %% [markdown]
# # Logical Functions & Lookup
#
# Q1. Pass / Fail ka Formula
# Question:
# Marks B2 ≥ 40 ho to Pass, warna Fail
# Answer (Formula):
# Copy code
#
# =IF(B2>=40,"Pass","Fail")
#
# Q2. Bonus ka Formula
# Condition:
# Sales > 40000 AND Attendance ≥ 90%
# Answer (Formula):
# Copy code
#
# =IF(AND(B2>40000,C2>=90),"Bonus","No Bonus")
#
# Q3. Nested IF Formula (Grade)
# Condition:
# ≥90 → A
# ≥75 → B
# ≥50 → C
# Otherwise → Fail
# Answer (Formula):
# Copy code
#
# =IF(B2>=90,"A",IF(B2>=75,"B",IF(B2>=50,"C","Fail")))
#
#
# Q4. Employee ID E103 ka Department
# Answer: Finance
# Formula (VLOOKUP):
# Copy code
#
# =VLOOKUP("E103",A2:C5,3,FALSE)
# Short Explanation:
# VLOOKUP ka use left column (EmpID) se value search karke right column (Department) ka data nikalne ke liye hota hai.
#
#
# Q5. Commission Rate (VLOOKUP)
# Question:
# Sales = ₹45,000
# Commission structure ke according rate nikalna hai.
# Answer (Formula):
# Copy code
#
# =VLOOKUP(45000,A2:B5,2,TRUE)
# Answer (Commission Rate): 10%
# 👉 Kyunki 45,000, 20,000 aur 50,000 ke beech aata hai.
#
#
# Q6. Leave Exceeded Check (IF Function)
# Condition:
# Agar Leaves Taken > Leaves Allowed → “Exceeded”
# Otherwise → “OK”
# Answer (Formula):
# Copy code
#
# =IF(B2>C2,"Exceeded","OK")
#
#
#
# Q7. Salary of EmpID = E105 (INDEX-MATCH)
# Question:
# EmpID E105 ki salary nikalni hai.
# Answer (Formula):
# Copy code
#
# =INDEX(B2:B5,MATCH("E105",A2:A5,0))
# Answer (Salary): 72000
#
# Q8. Department of EmpID = E303 (XLOOKUP)
# Question:
# EmpID E303 ka Department nikalna hai.
# Answer (Formula):
# Copy code
#
# =XLOOKUP("E303",A2:A5,B2:B5)
# Answer (Department): IT
